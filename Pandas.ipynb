# %%
import pandas as pd
import seaborn as sns
sns.set()

# %%
l = [1, 2, 3, 4, 5]
ser = pd.Series(l)

print("Series: ", ser)

data = {
    'a' : 10,
    'b' : 20,
    'c' : 30,
    'd' : 40,
}

ser = pd.Series(data)

print("Series: ", ser)

# %%
# Querying a Series

ser = pd.Series([1, 2, 3, 4, 5], index = ['a', 'b', 'c', 'd', 'e'])

ser['a']
ser.iloc[0]

ser.where(ser > 2, ser**2)
# print(ser)

# %%
# Dataframes
iris = pd.read_csv('Iris.csv')
print(iris.head())

# %%
print(iris.tail())

# %%
iris.iloc[10]

# %%
iris.iloc[10:20]

# %%
print(iris.iloc[10:20, 1:3])
iris[10:20][['SepalLengthCm', 'SepalWidthCm']]

# %%
iris.values

# %%
chunk_iris = pd.read_csv('Iris.csv', chunksize = 10)
for chunk in chunk_iris:
    print(chunk)

# %%
iris.describe()

# %%
iris['SepalLengthCm'].describe()

# %%
iris[iris['SepalLengthCm'] > 7]

# %%
iris.set_index('Id', inplace = True)
iris.loc[1]

# %%
iris.plot()
# Out:
# <AxesSubplot: xlabel='Id'>

# %%
iris.plot(kind = 'scatter', x = 'SepalLengthCm', y = 'SepalWidthCm')
# Out:
# <AxesSubplot: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
iris.plot(kind = 'scatter', x = 'SepalLengthCm', y = 'SepalWidthCm', c = 'PetalLengthCm')
# Out:
# <AxesSubplot: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
iris.plot(kind = 'scatter', x = 'SepalLengthCm', y = 'SepalWidthCm', c = 'PetalLengthCm', s = iris['PetalWidthCm']*20)
# Out:
# <AxesSubplot: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>
